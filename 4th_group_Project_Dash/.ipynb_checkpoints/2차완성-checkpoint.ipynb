# %%
# pip install dash_pivottable

# %%
import dash
from dash.dependencies import Input, Output
from dash import html
import dash_pivottable
from data import data

# %%
def Header(name, app):
    img_style = {"float": "right", "height": 40, "margin-right": 10}
    kma_logo = html.Img(src=app.get_asset_url("sig2.png"), style=img_style)
    sisul_logo = html.Img(src=app.get_asset_url("logo.gif"), style=img_style)
    fcseoul_logo = html.Img(src=app.get_asset_url("img_logo_gold.png"), style=img_style)
    

    return html.Div(
        [
            html.H1(name, style={"margin": 10, "display": "inline"}),
            html.A(fcseoul_logo, href="https://m.fcseoul.com/"),
            html.A(sisul_logo, href="https://www.sisul.or.kr/open_content/main/"),
            html.A(kma_logo, href="https://www.weather.go.kr/w/index.do"),
            
            html.A(
                html.Button(
                    "서울월드컵경기장",
                    style={
                        "float": "right",
                        "margin-right": "10px",
                        "margin-top": "5px",
                        "padding": "5px 10px",
                        "font-size": "15px",
                    },
                ),
                href="https://www.sisul.or.kr/open_content/worldcup/",
            ),
            html.Hr(),
        ]
    )


app = dash.Dash(__name__)
app.title = "Dash Pivottable"
server = app.server

# %%
app.layout = html.Div(
    [
        Header("서울월드컵경기장 수익 극대화", app),
        dash_pivottable.PivotTable(
            id="table",
            data=data,
            # cols=["Day of Week"],
            colOrder="key_a_to_z",
            # rows=["Party Size"],
            rowOrder="key_a_to_z",
            rendererName="Grouped Column Chart",
            aggregatorName="Average",
            vals=["Total Bill"],
            valueFilter={"Day of Week": {"Thursday": False}},
        ),
        html.Div(id="output"),
    ]
)


@app.callback(
    Output("output", "children"),
    [
        Input("table", "cols"),
        Input("table", "rows"),
        Input("table", "rowOrder"),
        Input("table", "colOrder"),
        Input("table", "aggregatorName"),
        Input("table", "rendererName"),
    ],
)
def display_props(cols, rows, row_order, col_order, aggregator, renderer):
    return [
        html.P(str(cols), id="columns"),
        html.P(str(rows), id="rows"),
        html.P(str(row_order), id="row_order"),
        html.P(str(col_order), id="col_order"),
        html.P(str(aggregator), id="aggregator"),
        html.P(str(renderer), id="renderer"),
    ]


if __name__ == "__main__":
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit
# 127.0.0.1 - - [21/Apr/2023 14:25:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:25:06] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:25:06] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:25:06] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:25:06] "GET /assets/img_logo_gold.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:25:06] "GET /assets/logo.gif HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:25:06] "GET /assets/sig2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:25:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:25:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:25:08] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:25:08] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:25:08] "GET /_favicon.ico?v=2.9.3 HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:25:08] "GET /assets/img_logo_gold.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:25:08] "GET /assets/logo.gif HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:25:08] "GET /assets/sig2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:25:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:26:39] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:26:39] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:26:39] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:26:39] "GET /assets/img_logo_gold.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:26:39] "GET /assets/logo.gif HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:26:39] "GET /assets/sig2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:26:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:26:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:26:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:26:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:27:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:28:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:29:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:29:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:29:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:31:16] "GET /assets/img_logo_gold.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:16] "GET /assets/logo.gif HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:16] "GET /assets/sig2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:31:18] "GET /assets/img_logo_gold.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:18] "GET /assets/logo.gif HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:18] "GET /assets/sig2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:31:21] "GET /assets/img_logo_gold.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:21] "GET /assets/logo.gif HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:21] "GET /assets/sig2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:31:26] "GET /assets/img_logo_gold.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:26] "GET /assets/logo.gif HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:26] "GET /assets/sig2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:31:26] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:03] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:03] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:03] "GET /assets/img_logo_gold.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:32:03] "GET /assets/logo.gif HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:32:03] "GET /assets/sig2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:32:03] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:29] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:30] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:31] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:32:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:33:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:56:46] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:56:46] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Apr/2023 14:56:46] "GET /assets/logo.gif HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:56:46] "GET /assets/img_logo_gold.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:56:46] "GET /assets/sig2.png HTTP/1.1" 304 -
# 127.0.0.1 - - [21/Apr/2023 14:56:46] "POST /_dash-update-component HTTP/1.1" 200 -
