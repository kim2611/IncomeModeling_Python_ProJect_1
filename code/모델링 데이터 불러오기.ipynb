# %%
import pandas as pd

# %%
df = pd.read_csv('/content/1차 전처리 완료_최종.csv', encoding = 'cp949')

# %%
df
# Out:
#              일시   관람인원    수입금(원)  사용일수(일) 폭염여부  강수여부   구름여부 습도여부  풍향 바람세기  \
# 0    2011-05-15  26008  38325470        1   일반    맑음     맑음   보통  남서   약풍
# 1    2011-05-21  14817  28484710        1   일반  약한 비     흐림   다습   북   약풍
# 2    2011-06-11  44358  43836790        1   일반    맑음     맑음   보통   서   약풍
# 3    2011-06-25  15414  28239910        1   일반    보통     흐림   다습   동   약풍
# 4    2011-07-09  28034  37067540        1   일반    보통  구름 많음   다습   동   무풍
# ..          ...    ...       ...      ...  ...   ...    ...  ...  ..  ...
# 162  2019-09-15  15236  44995210        1   일반    맑음     맑음   다습   북   약풍
# 163  2019-09-25   8429  39306280        1   일반    맑음  구름 많음   다습   북   무풍
# 164  2019-09-29  13914  60876030        1   일반    맑음     맑음   다습  남서   약풍
# 165  2019-11-03  19813  68202520        1   일반    맑음     맑음   보통   동   약풍
# 166  2019-11-23  16783  46329880        1   일반    맑음  구름 많음   보통   동   무풍
#
#     미세먼지 수준 할인여부
# 0        나쁨   평일
# 1        좋음   할인
# 2        보통   평일
# ...

# %%
df.columns
# Out:
# Index(['일시', '관람인원', '수입금(원)', '사용일수(일)', '폭염여부', '강수여부', '구름여부', '습도여부', '풍향',
#        '바람세기', '미세먼지 수준', '할인여부'],
#       dtype='object')

# %%
X = df[['폭염여부','강수여부', '구름여부', '습도여부', '풍향', '바람세기', '미세먼지 수준']]
y = df['할인여부']
